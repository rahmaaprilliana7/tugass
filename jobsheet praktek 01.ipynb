# %% [markdown]
# Praktikum 01. menghitung luas persegi panjang

# %%
p = int(input("Masukkan panjang: "))
l = int(input("Masukkan lebar: "))
luas = p * l
print("Luas persegi panjang =", luas)
# Out:
# Masukkan panjang: 2
# Masukkan lebar: 3
# Luas persegi panjang = 6

# %% [markdown]
# prkatikum 02. menghitung luas segitiga

# %%
import math
a = int(input("masukkan sisi a:"))
b = int (input("masukkan sisi b:"))
c = int (input("masukkan sisi c: ") )
s = (a + b + c) / 2
luas= math.sqrt(s *(s - a) * (s - b) * (s - c))
print("luas segitiga =", luas)
# Out:
# masukkan sisi a:1
# masukkan sisi b:1
# masukkan sisi c2
# luas segitiga = 0.0

# %% [markdown]
# praktikum 03. konfersi sushu celcius ke fahrenheit

# %%
import math
c = int (input ("masukkan suhu celcius: "))
f =  (c * 9/5) + 32
print ("hasil konversi suhu:",f )
# Out:
# masukkan suhu celcius: 4
# hasil konversi suhu: 39.2

# %% [markdown]
# Praktikum 04. Menghitung Umur Berdasarkan Tahun Lahir

# %%
tahun_lahir= int(input("tahun lahir anda: "))
tahun_sekarang= int(input('tahun sekarang: '))
umur= tahun_sekarang - tahun_lahir
print ("umur anda sekarang: ", umur)
# Out:
# umur anda sekarang:  20
